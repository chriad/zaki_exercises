# %%
import pandas as pd
import numpy as np

# %%
# !head -n2 iris.txt
# Out:
# 5.9,3,4.2,1.5,"Iris-versicolor"
# 6.9,3.1,4.9,1.5,"Iris-versicolor"

# %%
columns = 'sepal_length,sepal_width,petal_length,petal_width,iris_class'.split(',')
df = pd.read_csv('./iris.txt', header=None, names=columns)
df.head()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
enc = LabelEncoder()

# %%
encoded_labels = enc.fit_transform(df.iris_class.values)

# %%
enc.classes_
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
encoded_labels
# Out:
# array([1, 1, 1, 0, 1, 0, 2, 2, 2, 2, 0, 0, 1, 2, 0, 0, 0, 1, 0, 2, 2, 2, 0,
#        1, 2, 0, 1, 0, 2, 2, 0, 0, 2, 1, 1, 1, 1, 0, 1, 2, 1, 1, 2, 2, 1, 0,
#        2, 1, 0, 0, 1, 2, 0, 2, 0, 2, 2, 2, 1, 1, 2, 2, 0, 0, 1, 1, 2, 0, 0,
#        0, 2, 2, 1, 0, 0, 0, 0, 2, 0, 1, 2, 1, 1, 2, 1, 1, 1, 2, 0, 2, 0, 0,
#        2, 1, 2, 2, 1, 1, 1, 1, 1, 1, 2, 2, 1, 0, 0, 2, 0, 0, 1, 0, 1, 0, 1,
#        0, 2, 2, 2, 1, 2, 0, 1, 1, 0, 0, 1, 0, 1, 2, 0, 2, 2, 0, 0, 0, 0, 1,
#        2, 1, 2, 2, 1, 1, 2, 0, 1, 2, 2, 0])

# %%
ohe = OneHotEncoder()

# %%
ohe
# Out:
# OneHotEncoder(categorical_features='all', dtype=<type 'float'>,
#        n_values='auto', sparse=True)

# %%
new_features = ohe.fit_transform(encoded_labels.reshape((-1,1))) # doesen't work, first convert to integer_classes

# %%
new_features
# Out:
# <150x3 sparse matrix of type '<type 'numpy.float64'>'
# 	with 150 stored elements in Compressed Sparse Row format>

# %%
# %load data_loader.py

# %%
one_hot_encode(df,'iris_class')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  iris_class_0  \
# 0             5.9          3.0           4.2          1.5             0
# 1             6.9          3.1           4.9          1.5             0
# 2             6.6          2.9           4.6          1.3             0
# 3             4.6          3.2           1.4          0.2             1
# 4             6.0          2.2           4.0          1.0             0
# 5             4.7          3.2           1.3          0.2             1
# 6             6.5          3.0           5.8          2.2             0
# 7             5.8          2.7           5.1          1.9             0
# 8             6.7          3.1           5.6          2.4             0
# 9             6.7          2.5           5.8          1.8             0
# 10            5.1          3.7           1.5          0.4             1
# 11            5.1          3.8           1.5          0.3             1
# ...
